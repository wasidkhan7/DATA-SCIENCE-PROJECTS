# %% [markdown]
# # DATA ANALYSIS PRACTICE

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("C:/Users/Dubai Laptop/world_population_data.csv")

# %%
df.head(10)
# Out:
#    rank cca3        country      continent  2023 population  2022 population  \
# 0     1  IND          India           Asia       1428627663       1417173173
# 1     2  CHN          China           Asia       1425671352       1425887337
# 2     3  USA  United States  North America        339996563        338289857
# 3     4  IDN      Indonesia           Asia        277534122        275501339
# 4     5  PAK       Pakistan           Asia        240485658        235824862
# 5     6  NGA        Nigeria         Africa        223804632        218541212
# 6     7  BRA         Brazil  South America        216422446        215313498
# 7     8  BGD     Bangladesh           Asia        172954319        171186372
# 8     9  RUS         Russia         Europe        144444359        144713314
# 9    10  MEX         Mexico  North America        128455567        127504125
#
#    2020 population  2015 population  2010 population  2000 population  \
# ...

# %%
df=df.rename(columns={'cca3':'shortname'})

# %%
df.head()
# Out:
#    rank shortname        country      continent  2023 population  \
# 0     1       IND          India           Asia       1428627663
# 1     2       CHN          China           Asia       1425671352
# 2     3       USA  United States  North America        339996563
# 3     4       IDN      Indonesia           Asia        277534122
# 4     5       PAK       Pakistan           Asia        240485658
#
#    2022 population  2020 population  2015 population  2010 population  \
# 0       1417173173       1396387127       1322866505       1240613620
# 1       1425887337       1424929781       1393715448       1348191368
# 2        338289857        335942003        324607776        311182845
# 3        275501339        271857970        259091970        244016173
# 4        235824862        227196741        210969298        194454498
#
#    2000 population  1990 population  1980 population  1970 population  \
# 0       1059633675        870452165        696828385        557501301
# ...

# %%
df.columns
# Out:
# Index(['rank', 'shortname', 'country', 'continent', '2023 population',
#        '2022 population', '2020 population', '2015 population',
#        '2010 population', '2000 population', '1990 population',
#        '1980 population', '1970 population', 'area (km²)', 'density (km²)',
#        'growth rate', 'world percentage'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# rank                0
# shortname           0
# country             0
# continent           0
# 2023 population     0
# 2022 population     0
# 2020 population     0
# 2015 population     0
# 2010 population     0
# 2000 population     0
# 1990 population     0
# 1980 population     0
# 1970 population     0
# area (km²)          0
# density (km²)       0
# growth rate         0
# world percentage    0
# dtype: int64

# %%
df.dtypes
# Out:
# rank                  int64
# shortname            object
# country              object
# continent            object
# 2023 population       int64
# 2022 population       int64
# 2020 population       int64
# 2015 population       int64
# 2010 population       int64
# 2000 population       int64
# 1990 population       int64
# 1980 population       int64
# 1970 population       int64
# area (km²)          float64
# density (km²)         int64
# growth rate          object
# world percentage     object
# dtype: object

# %%
df.describe(include='all')
# Out:
#               rank shortname country continent  2023 population  \
# count   234.000000       234     234       234     2.340000e+02
# unique         NaN       234     234         6              NaN
# top            NaN       IND   India    Africa              NaN
# freq           NaN         1       1        57              NaN
# mean    117.500000       NaN     NaN       NaN     3.437442e+07
# std      67.694165       NaN     NaN       NaN     1.373864e+08
# min       1.000000       NaN     NaN       NaN     5.180000e+02
# 25%      59.250000       NaN     NaN       NaN     4.225982e+05
# 50%     117.500000       NaN     NaN       NaN     5.643895e+06
# 75%     175.750000       NaN     NaN       NaN     2.324537e+07
# max     234.000000       NaN     NaN       NaN     1.428628e+09
#
#         2022 population  2020 population  2015 population  2010 population  \
# count      2.340000e+02     2.340000e+02     2.340000e+02     2.340000e+02
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   rank              234 non-null    int64
#  1   shortname         234 non-null    object
#  2   country           234 non-null    object
#  3   continent         234 non-null    object
#  4   2023 population   234 non-null    int64
#  5   2022 population   234 non-null    int64
#  6   2020 population   234 non-null    int64
#  7   2015 population   234 non-null    int64
#  8   2010 population   234 non-null    int64
#  9   2000 population   234 non-null    int64
#  10  1990 population   234 non-null    int64
#  11  1980 population   234 non-null    int64
#  12  1970 population   234 non-null    int64
#  13  area (km²)        234 non-null    float64
#  14  density (km²)     234 non-null    int64
#  15  growth rate       234 non-null    object
# ...

# %%
df['area (km²)']=df['area (km²)']/df['area (km²)'].max()
df['area (km²)']
# Out:
# 0      1.922765e-01
# 1      5.677169e-01
# 2      5.481622e-01
# 3      1.113898e-01
# 4      5.157910e-02
#            ...
# 229    5.965526e-06
# 230    7.119445e-04
# 231    1.526473e-05
# 232    7.018265e-07
# 233    2.573364e-08
# Name: area (km²), Length: 234, dtype: float64

# %%
df.head()
# Out:
#    rank shortname        country      continent  2023 population  \
# 0     1       IND          India           Asia       1428627663
# 1     2       CHN          China           Asia       1425671352
# 2     3       USA  United States  North America        339996563
# 3     4       IDN      Indonesia           Asia        277534122
# 4     5       PAK       Pakistan           Asia        240485658
#
#    2022 population  2020 population  2015 population  2010 population  \
# 0       1417173173       1396387127       1322866505       1240613620
# 1       1425887337       1424929781       1393715448       1348191368
# 2        338289857        335942003        324607776        311182845
# 3        275501339        271857970        259091970        244016173
# 4        235824862        227196741        210969298        194454498
#
#    2000 population  1990 population  1980 population  1970 population  \
# 0       1059633675        870452165        696828385        557501301
# ...

# %%
df[['rank','2023 population',
       '2022 population', '2020 population', '2015 population',
       '2010 population', '2000 population', '1990 population',
       '1980 population', '1970 population', 'area (km²)', 'density (km²)']].corr()  # +ve 1 correletion
# Out:
#                      rank  2023 population  2022 population  2020 population  \
# rank             1.000000        -0.359637        -0.358351        -0.355817
# 2023 population -0.359637         1.000000         0.999984         0.999870
# 2022 population -0.358351         0.999984         1.000000         0.999946
# 2020 population -0.355817         0.999870         0.999946         1.000000
# 2015 population -0.351131         0.999296         0.999490         0.999763
# 2010 population -0.347323         0.998326         0.998629         0.999105
# 2000 population -0.340801         0.994023         0.994605         0.995583
# 1990 population -0.335771         0.986358         0.987228         0.988724
# 1980 population -0.334769         0.979229         0.980285         0.982121
# 1970 population -0.334827         0.971968         0.973162         0.975254
# area (km²)      -0.384185         0.452640         0.453411         0.454993
# ...

# %%
corr=plt.scatter(x=df['2020 population'] , y=df['2000 population'] , color='red')   # oops found outliers
plt.xlabel('2020 population')
plt.ylabel('2000 population')
plt.title('COMPARING YEARLY POPULATION')
plt.show()

# %%
reg=sns.regplot(x=df['2020 population'] , y=df['2000 population'] , data=df)  #finding regression between yearly population
plt.xlabel('2020 population',color='green')
plt.ylabel('2000 population',color='green')
plt.title('COMPARING REGRESSION YEARLY POPULATION' ,color='green')
plt.show()

# %%
bx=sns.boxplot(x=df['2020 population'] , y=df['2000 population'] , data=df) #first we need to remove outline from these data

# %%
#grouping attributes
df_group=df[['2023 population',
       '2022 population', '2020 population', '2015 population',
       '2010 population', '2000 population', '1990 population',
       '1980 population', '1970 population']]

# %%
df_group = df_group.groupby(['2000 population'], 
as_index=False).mean()
df_group
# Out:
#      2000 population  2023 population  2022 population  2020 population  \
# 0                651     5.180000e+02     5.100000e+02     5.200000e+02
# 1               1666     1.893000e+03     1.871000e+03     1.827000e+03
# 2               2074     1.935000e+03     1.934000e+03     1.942000e+03
# 3               3080     3.791000e+03     3.780000e+03     3.747000e+03
# 4               5138     4.386000e+03     4.390000e+03     4.500000e+03
# ..               ...              ...              ...              ...
# 229        175873720     2.164224e+08     2.153135e+08     2.131963e+08
# 230        214072421     2.775341e+08     2.755013e+08     2.718580e+08
# 231        282398554     3.399966e+08     3.382899e+08     3.359420e+08
# 232       1059633675     1.428628e+09     1.417173e+09     1.396387e+09
# 233       1264099069     1.425671e+09     1.425887e+09     1.424930e+09
#
#      2015 population  2010 population  1990 population  1980 population  \
# ...

# %%
grouped_pivot = df_group.pivot(index='1980 population',columns='2022 population') 
grouped_pivot
# Out:
#                 2000 population                                         \
# 2022 population    5.100000e+02 1.871000e+03 1.934000e+03 3.780000e+03
# 1980 population
# 733.0                     651.0          NaN          NaN          NaN
# 1647.0                      NaN       1666.0          NaN          NaN
# 2240.0                      NaN          NaN          NaN       3080.0
# 2983.0                      NaN          NaN          NaN          NaN
# 3637.0                      NaN          NaN       2074.0          NaN
# ...                         ...          ...          ...          ...
# 138257420.0                 NaN          NaN          NaN          NaN
# 148177096.0                 NaN          NaN          NaN          NaN
# 223140018.0                 NaN          NaN          NaN          NaN
# 696828385.0                 NaN          NaN          NaN          NaN
# 982372466.0                 NaN          NaN          NaN          NaN
#
# ...

# %% [markdown]
# # MODEL DEVELOPMENT  (ML Basics)

# %% [markdown]
# # simple linear regression model

# %%
from sklearn.linear_model import LinearRegression

# %%
df=pd.read_csv("C:/Users/Dubai Laptop/kc_house_data.csv")

# %%
df.head(10)
# Out:
#            id             date      price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000   221900.0         3       1.00         1180
# 1  6414100192  20141209T000000   538000.0         3       2.25         2570
# 2  5631500400  20150225T000000   180000.0         2       1.00          770
# 3  2487200875  20141209T000000   604000.0         4       3.00         1960
# 4  1954400510  20150218T000000   510000.0         3       2.00         1680
# 5  7237550310  20140512T000000  1225000.0         4       4.50         5420
# 6  1321400060  20140627T000000   257500.0         3       2.25         1715
# 7  2008000270  20150115T000000   291850.0         3       1.50         1060
# 8  2414600126  20150415T000000   229500.0         3       1.00         1780
# 9  3793500160  20150312T000000   323000.0         3       2.50         1890
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# ...

# %%
df.describe(include='all')
# Out:
#                   id             date         price      bedrooms  \
# count   2.161300e+04            21613  2.161300e+04  21613.000000
# unique           NaN              372           NaN           NaN
# top              NaN  20140623T000000           NaN           NaN
# freq             NaN              142           NaN           NaN
# mean    4.580302e+09              NaN  5.400881e+05      3.370842
# std     2.876566e+09              NaN  3.671272e+05      0.930062
# min     1.000102e+06              NaN  7.500000e+04      0.000000
# 25%     2.123049e+09              NaN  3.219500e+05      3.000000
# 50%     3.904930e+09              NaN  4.500000e+05      3.000000
# 75%     7.308900e+09              NaN  6.450000e+05      4.000000
# max     9.900000e+09              NaN  7.700000e+06     33.000000
#
#            bathrooms   sqft_living      sqft_lot        floors    waterfront  \
# count   21613.000000  21613.000000  2.161300e+04  21613.000000  21613.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %% [markdown]
# now here we need to drop price (dependent) column from the dataset to make it alone dependent variable because we need to find it , and then will predict in order to find them customly

# %%
price=df['price']
price
# Out:
# 0        221900.0
# 1        538000.0
# 2        180000.0
# 3        604000.0
# 4        510000.0
#            ...
# 21608    360000.0
# 21609    400000.0
# 21610    402101.0
# 21611    400000.0
# 21612    325000.0
# Name: price, Length: 21613, dtype: float64

# %%
new_df=df.drop(['price'] , axis=1)

# %%
new_df.head()
# Out:
#            id             date  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  7129300520  20141013T000000         3       1.00         1180      5650
# 1  6414100192  20141209T000000         3       2.25         2570      7242
# 2  5631500400  20150225T000000         2       1.00          770     10000
# 3  2487200875  20141209T000000         4       3.00         1960      5000
# 4  1954400510  20150218T000000         3       2.00         1680      8080
#
#    floors  waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 0     1.0           0     0          3      7        1180              0
# 1     2.0           0     0          3      7        2170            400
# 2     1.0           0     0          3      6         770              0
# 3     1.0           0     0          5      7        1050            910
# 4     1.0           0     0          3      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# ...

# %%
lr=LinearRegression()       #making linear regression object

# %%
#training linear regression model
x=df[['bedrooms']]
y=df['price']
lr.fit(x,y)
# Out:
# LinearRegression()

# %%
# Generate output predictions 
y_hat=lr.predict(x)       # it will generate all output present in house bedroom's the dataset
y_hat
# Out:
# array([494950.73585377, 494950.73585377, 373234.60934194, ...,
#        373234.60934194, 494950.73585377, 373234.60934194])

# %%
yhat=lr.predict([[4]])          #another way of finding price
yhat
# Out:
# C:\Users\Dubai Laptop\New folder\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([616666.86236561])

# %%
lr.coef_
# Out:
# array([121716.12651184])

# %%
lr.intercept_
# Out:
# 129802.35631825816

# %% [markdown]
# # multiple linear regression

# %%
lr=LinearRegression()

# %%
x=new_df[['bedrooms','bathrooms','floors','grade']]
y=df['price']
lr.fit(x,y)
# finding R2 score for model fitting , how colse the model fit to data?
r2_score=lr.score(x,y)
r2_score       # if r2 were 1 instead of 0.4, it would be perfect fit
# Out:
# 0.4662314737773686

# %%
# generating prediction output
y_ht=lr.predict([[4,3,1,7]])           
y_ht
# Out:
# C:\Users\Dubai Laptop\New folder\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([531428.22958179])

# %% [markdown]
# " since i havent add all the attributes(columns) to x=.....(independent variables), however its output might be not accurate  "

# %%
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
residual=sns.residplot(x=df['bedrooms'] , y=df['price'])    #residual plot has straight horizontal line in graph
plt.title('residual plot',color='blue')
plt.xlabel('bedrooms',color='blue')
plt.ylabel('price', color='blue')
# Out:
# Text(0, 0.5, 'price')

# %%
regplot=sns.regplot(x=df['bedrooms'] , y=df['price'])      #regression plot has left to right in a slope line 
plt.title('REGRESSION PLOT',color='blue')
plt.xlabel('bedrooms',color='blue')
plt.ylabel('price', color='blue')
# so its in +ve correlation
# Out:
# Text(0, 0.5, 'price')

# %%
scatter=plt.scatter(x=df['bedrooms'] , y=df['price'])       # it has no line in a graph 
plt.title('SCATTER PLOT',color='blue')
plt.xlabel('bedrooms',color='blue')
plt.ylabel('price', color='blue')
# Out:
# Text(0, 0.5, 'price')

# %%
#distribution plot
dist=sns.distplot(df['price'] , hist=False)  #false will off histogram on which line is created
plt.title('DISTRIBUTION PLOT',color='blue')
# Out:
# C:\Users\Dubai Laptop\AppData\Local\Temp\ipykernel_9028\3267473488.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   dist=sns.distplot(df['price'] , hist=False)  #false will off histogram on which line is created
# Text(0.5, 1.0, 'DISTRIBUTION PLOT')

# %%
# polynomial regression
x=new_df['bedrooms']
y=df['price']
n=3
pol=np.polyfit(x,y,n)   # creates the polynomial features of order n 

f=np.poly1d(pol)
yh=f(x)
yh
# Out:
# array([489790.31960142, 489790.31960142, 373542.9357629 , ...,
#        373542.9357629 , 489790.31960142, 373542.9357629 ])

# %% [markdown]
# # MOdel Evaluation and refinement

# %%
#MSE , R2_SCORE

# %%
x=new_df[['bedrooms']]
y=df['price']

lr.fit(x,y)      # model fitting 

y_hat=lr.predict([[3]])  #generating prediction output 
y_hat
# Out:
# C:\Users\Dubai Laptop\New folder\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([494950.73585377])

# %%
#r2_score
r2_score=lr.score(x,y)
r2_score          # it is not closest to 1
# Out:
# 0.09507947467657651

# %%
x=new_df['bedrooms']
y=df['price']
n=3

pol=np.polyfit(x,y,n)   
p=np.poly1d(pol)    # variables should be 1D
output=p(x)
output
        #r2_score for polynomial regression
from sklearn.metrics import r2_score
R2_score=r2_score(y,p(x))
R2_score                 #since it is a good fit
# Out:
# 0.10014879655302766

# %%
#MSE
from sklearn.metrics import mean_squared_error
mse=mean_squared_error(y,y_hat)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[49], line 3
#       1 #MSE
#       2 from sklearn.metrics import mean_squared_error
# ----> 3 mse=mean_squared_error(y,y_hat)
#
# File ~\New folder\Lib\site-packages\sklearn\utils\_param_validation.py:211, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     205 try:
#     206     with config_context(
#     207         skip_parameter_validation=(
#     208             prefer_skip_nested_validation or global_skip_validation
#     209         )
#     210     ):
# --> 211         return func(*args, **kwargs)
#     212 except InvalidParameterError as e:
#     213     # When the function is just a wrapper around an estimator, we allow
#     214     # the function to delegate validation to the estimator, but we replace
#     215     # the name of the estimator by the name of the function in the error
# ...

# %% [markdown]
# # TRAIN TEST SPLIT

# %%
from sklearn.model_selection import train_test_split

y_data=df['price']       # target variable
x_data=df.drop(['price'], axis=1)  # all data frame other than price column
x_train,x_test,y_train,y_test=train_test_split(y_data ,x_data , test_size=0.2 , random_state=1)

x_train,x_test,y_train,y_test
# Out:
# (7291      353000.0
#  14835     300523.0
#  15880     435000.0
#  8812      800000.0
#  17220     417500.0
#             ...
#  10955     571000.0
#  17289    1350000.0
#  5192      650000.0
#  12172     437000.0
#  235      1025000.0
#  Name: price, Length: 17290, dtype: float64,
#  15544     459000.0
#  17454     445000.0
#  21548    1057000.0
#  3427      732350.0
#  8809      235000.0
#             ...
#  13597     965000.0
#  9648      359950.0
#  18627     260000.0
#  9553     1795000.0
#  14200     418000.0
#  Name: price, Length: 4323, dtype: float64,
#                 id             date  bedrooms  bathrooms  sqft_living  \
#  7291   4058200630  20141002T000000         3       1.75         2190
#  14835  3613600150  20150105T000000         3       2.50         2370
#  15880  7170200080  20140617T000000         2       1.00         1230
#  8812   9542300530  20141124T000000         4       2.25         2510
# ...

# %%
x_train
# Out:
# 7291      353000.0
# 14835     300523.0
# 15880     435000.0
# 8812      800000.0
# 17220     417500.0
#            ...
# 10955     571000.0
# 17289    1350000.0
# 5192      650000.0
# 12172     437000.0
# 235      1025000.0
# Name: price, Length: 17290, dtype: float64

# %%
y_train
# Out:
#                id             date  bedrooms  bathrooms  sqft_living  \
# 7291   4058200630  20141002T000000         3       1.75         2190
# 14835  3613600150  20150105T000000         3       2.50         2370
# 15880  7170200080  20140617T000000         2       1.00         1230
# 8812   9542300530  20141124T000000         4       2.25         2510
# 17220  3626039028  20140818T000000         3       1.00         1160
# ...           ...              ...       ...        ...          ...
# 10955  3630110510  20140804T000000         3       2.50         1920
# 17289  6813600605  20150128T000000         4       4.50         3420
# 5192    224069145  20150401T000000         3       1.75         1970
# 12172   520700125  20140805T000000         3       2.25         1980
# 235    1762600320  20140610T000000         5       4.00         3760
#
#        sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# ...

# %%
x_test
# Out:
# 15544     459000.0
# 17454     445000.0
# 21548    1057000.0
# 3427      732350.0
# 8809      235000.0
#            ...
# 13597     965000.0
# 9648      359950.0
# 18627     260000.0
# 9553     1795000.0
# 14200     418000.0
# Name: price, Length: 4323, dtype: float64

# %%
 y_test
# Out:
#                id             date  bedrooms  bathrooms  sqft_living  \
# 15544  1310430130  20141009T000000         4       2.75         2790
# 17454  2540830020  20150401T000000         3       2.25         1630
# 21548  8835770330  20140819T000000         2       1.50         2370
# 3427   7732400490  20141105T000000         4       2.50         2270
# 8809      2800031  20150401T000000         3       1.00         1430
# ...           ...              ...       ...        ...          ...
# 13597  5608010650  20150408T000000         4       2.50         3420
# 9648   2310100180  20141107T000000         3       2.50         2210
# 18627  9264921020  20140908T000000         3       1.50         1750
# 9553   9320100090  20140610T000000         5       3.25         5270
# 14200  4046600220  20141017T000000         3       1.75         1500
#
#        sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# ...

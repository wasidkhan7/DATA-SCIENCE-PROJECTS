# %% [markdown]
# # DATA VISUALIZATION BEGINNERS PROJECT

# %% [markdown]
# **PROJECT OVERVIEW :**
#
#                 IN THIS PROJECT WE WILL HANDLING WITH THE DATA_SCIENCE SALARY DATASET .
#                 IN WHICH WE WILL FIRST FOCUS ON DATA AND STATS ANALYSIS AND THEN WILL VISUALIZE THE DATA IN ORDER TO
#                 EXTRACT MEANINGFUL INSIGHTS FROM THE DATASET THROUGH DIFFERENT PLOTTING METHODS.

# %% [markdown]
# **TABLE OF CONTENT :**
#
#     . COVERED ALL IMPORTANT VISUALIZATION FUNCTIONS IN THIS PROJECT
#     . data loading and data analysis
#     . data cleaning
#     . statistical analysis
#     . using all type of plotting graphs for the dataset
#     . using matplotlib library **
#     . using seaborn library   **
#     . using folium library   **

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("C:/Users/Dubai Laptop/data_science_salaries.csv")

# %%
df
# Out:
#                      job_title experience_level employment_type work_models  \
# 0                Data Engineer        Mid-level       Full-time      Remote
# 1                Data Engineer        Mid-level       Full-time      Remote
# 2               Data Scientist     Senior-level       Full-time      Remote
# 3               Data Scientist     Senior-level       Full-time      Remote
# 4                 BI Developer        Mid-level       Full-time     On-site
# ...                        ...              ...             ...         ...
# 6594        Staff Data Analyst      Entry-level        Contract      Hybrid
# 6595        Staff Data Analyst  Executive-level       Full-time     On-site
# 6596  Machine Learning Manager     Senior-level       Full-time      Hybrid
# 6597             Data Engineer        Mid-level       Full-time      Hybrid
# 6598            Data Scientist     Senior-level       Full-time     On-site
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6599 entries, 0 to 6598
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   job_title           6599 non-null   object
#  1   experience_level    6599 non-null   object
#  2   employment_type     6599 non-null   object
#  3   work_models         6599 non-null   object
#  4   work_year           6599 non-null   int64
#  5   employee_residence  6599 non-null   object
#  6   salary              6599 non-null   int64
#  7   salary_currency     6599 non-null   object
#  8   salary_in_usd       6599 non-null   int64
#  9   company_location    6599 non-null   object
#  10  company_size        6599 non-null   object
# dtypes: int64(3), object(8)
# memory usage: 567.2+ KB

# %%
df.describe(include='all')
# Out:
#             job_title experience_level employment_type work_models  \
# count            6599             6599            6599        6599
# unique            132                4               4           3
# top     Data Engineer     Senior-level       Full-time     On-site
# freq             1307             4105            6552        3813
# mean              NaN              NaN             NaN         NaN
# std               NaN              NaN             NaN         NaN
# min               NaN              NaN             NaN         NaN
# 25%               NaN              NaN             NaN         NaN
# 50%               NaN              NaN             NaN         NaN
# 75%               NaN              NaN             NaN         NaN
# max               NaN              NaN             NaN         NaN
#
#           work_year employee_residence        salary salary_currency  \
# count   6599.000000               6599  6.599000e+03            6599
# ...

# %%
df.head()
# Out:
#         job_title experience_level employment_type work_models  work_year  \
# 0   Data Engineer        Mid-level       Full-time      Remote       2024
# 1   Data Engineer        Mid-level       Full-time      Remote       2024
# 2  Data Scientist     Senior-level       Full-time      Remote       2024
# 3  Data Scientist     Senior-level       Full-time      Remote       2024
# 4    BI Developer        Mid-level       Full-time     On-site       2024
#
#   employee_residence  salary salary_currency  salary_in_usd company_location  \
# 0      United States  148100             USD         148100    United States
# 1      United States   98700             USD          98700    United States
# 2      United States  140032             USD         140032    United States
# 3      United States  100022             USD         100022    United States
# 4      United States  120000             USD         120000    United States
#
#   company_size
# 0       Medium
# 1       Medium
# ...

# %%
df.isnull().sum()
# Out:
# job_title             0
# experience_level      0
# employment_type       0
# work_models           0
# work_year             0
# employee_residence    0
# salary                0
# salary_currency       0
# salary_in_usd         0
# company_location      0
# company_size          0
# dtype: int64

# %%
df.columns
# Out:
# Index(['job_title', 'experience_level', 'employment_type', 'work_models',
#        'work_year', 'employee_residence', 'salary', 'salary_currency',
#        'salary_in_usd', 'company_location', 'company_size'],
#       dtype='object')

# %% [markdown]
# # PLOTTING WITH MATPLOTLIB

# %% [markdown]
# # lineplot

# %%
lineplot=df.plot(x='job_title' ,y='salary' ,kind='line' , linewidth=2 , figsize=(21,6),color='blue')
plt.title('salary VS Job',color='blue')
plt.xlabel('JOBS TITLE',color='blue')
plt.ylabel('SALARY',color='blue')
# Out:
# Text(0, 0.5, 'SALARY')

# %% [markdown]
# # AREA PLOT

# %%
area_df=df[['work_year','salary_in_usd','job_title']]
area_df.head(100)
area_df
# Out:
#       work_year  salary_in_usd                 job_title
# 0          2024         148100             Data Engineer
# 1          2024          98700             Data Engineer
# 2          2024         140032            Data Scientist
# 3          2024         100022            Data Scientist
# 4          2024         120000              BI Developer
# ...         ...            ...                       ...
# 6594       2020          44753        Staff Data Analyst
# 6595       2020          15000        Staff Data Analyst
# 6596       2020         117104  Machine Learning Manager
# 6597       2020          74130             Data Engineer
# 6598       2020          91237            Data Scientist
#
# [6599 rows x 3 columns]

# %%
areaplot=area_df.plot(kind='area', figsize=(19,7))
plt.title('SAlARY VS WORK YEAR',color='green')
plt.xlabel('WORK_YEAR  ',color='green')
plt.ylabel('SALARY',color='green')
# Out:
# Text(0, 0.5, 'SALARY')

# %% [markdown]
# # histogram

# %%
hist_df=df[['work_year','salary']]
hist_df=hist_df.head(100)
hist_df
# Out:
#     work_year  salary
# 0        2024  148100
# 1        2024   98700
# 2        2024  140032
# 3        2024  100022
# 4        2024  120000
# ..        ...     ...
# 95       2024  258720
# 96       2024  160000
# 97       2024  154800
# 98       2024   76300
# 99       2024  170200
#
# [100 rows x 2 columns]

# %%
histo=hist_df.plot(kind='hist', figsize=(15,7), bins=10)

# %% [markdown]
# # bar chart

# %%
df.columns
# Out:
# Index(['job_title', 'experience_level', 'employment_type', 'work_models',
#        'work_year', 'employee_residence', 'salary', 'salary_currency',
#        'salary_in_usd', 'company_location', 'company_size'],
#       dtype='object')

# %%
unique_workyear=df['work_year'].unique()
unique_workyear
# Out:
# array([2024, 2023, 2022, 2021, 2020], dtype=int64)

# %%
bar_df=df[['work_year','salary']]
bar_df=bar_df.head(100)

# %%
barchart =bar_df.plot(x='work_year' ,y='salary',kind='bar', figsize=(28,7))

# %% [markdown]
# ## pie plot

# %%
pie_df =df[['work_year','salary'] ]
pie_df=pie_df.head(5)
pie_df
# Out:
#    work_year  salary
# 0       2024  148100
# 1       2024   98700
# 2       2024  140032
# 3       2024  100022
# 4       2024  120000

# %%
pie=pie_df.plot(y='work_year',kind='pie', figsize=(11,7))

# %% [markdown]
# # boxplot

# %%
box_df =df[['work_year','salary'] ]
box_df=pie_df.head(5)
box_df
box=box_df.plot(kind='box', y='salary')

# %% [markdown]
# # scatterplot

# %%
scatter=df.plot(x='work_year',y='salary',kind='scatter', figsize=(22,7))

# %% [markdown]
# ### creating subplots

# %%
subplot=plt.subplots(ncols=2 , nrows=2)

# %% [markdown]
# # PLOTTING WITH SEABORN

# %% [markdown]
# **plotting with:**
#
#
#     . regression plot
#     . count plot
#     . scatter plot
#     . distribution plot
#     . barplot
#     . catagorical plot

# %%
df.head()
# Out:
#         job_title experience_level employment_type work_models  work_year  \
# 0   Data Engineer        Mid-level       Full-time      Remote       2024
# 1   Data Engineer        Mid-level       Full-time      Remote       2024
# 2  Data Scientist     Senior-level       Full-time      Remote       2024
# 3  Data Scientist     Senior-level       Full-time      Remote       2024
# 4    BI Developer        Mid-level       Full-time     On-site       2024
#
#   employee_residence  salary salary_currency  salary_in_usd company_location  \
# 0      United States  148100             USD         148100    United States
# 1      United States   98700             USD          98700    United States
# 2      United States  140032             USD         140032    United States
# 3      United States  100022             USD         100022    United States
# 4      United States  120000             USD         120000    United States
#
#   company_size
# 0       Medium
# 1       Medium
# ...

# %%
reg=sns.regplot(x='work_year', y='salary', data=df )
plt.figure(figsize=(29,10))

# %% [markdown]
# # countplot

# %%
count=sns.countplot(x='experience_level', data=df)
plt.title('COUNTPLOT OF EXPERIENCE LEVEL', color='green')
plt.xlabel(' EXPERIENCE LEVEL', color='green')
plt.ylabel('COUNT', color='green')
plt.legend()         # legend is ignored due to underscore(-) present in features
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
worktype_count=sns.countplot(x='work_models' , data=df)

# %% [markdown]
# # barplot

# %%
bar=sns.barplot(x='company_location',y='salary' ,data=df )         # x requires numeric variables

# %% [markdown]
# # PLOTTING  FOLIUM

# %%
import folium

# %%
canada=folium.Map(location=[556.130,-106.35], zoom_start=4)
canada
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
marker=folium.Marker(location=[556.130,-106.35], tooltip='marker' ,tiles='Stamen Terrain').add_to(canada)
marker
